# %%
print(1)
# Out:
# 1

# %%
1+1
# Out:
# 2

# %%
## one line comment
''' multi line comment
second line not work in jupiter notebook

print
# Out:
#   Cell In[12], line 2
#     ''' multi line comment
#     ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 5)

# %%
print('krish')
# Out:
# krish

# %% [markdown]
# ### INDENTATIONERROR
# i am siddharth i am just checking the line commenting

# %%
age=21
type(age)
# Out:
# int

# %%
age=21
name="siddharth"
height=5.8
check=True
print("age :",age)
print("name :",name)
print("height :",height)
print("check :",check)
# Out:
# age : 21
# name : siddharth
# height : 5.8
# check : True

# %%
age='32'
print(type(age))
print(type(int(age)))

##But if we try to convert a non-numeric string to an integer, it will raise a ValueError:  
age='thirty-two'
print(type(int(age)))
# Out:
# <class 'str'>
# <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 7
#       5 ##But if we try to convert a non-numeric string to an integer, it will raise a ValueError:
#       6 age='thirty-two'
# ----> 7 print(type(int(age)))
#
# ValueError: invalid literal for int() with base 10: 'thirty-two'

# %%
## Python allows us to change the data type when the program is running
var=21
print(var,type(var))
var="siddharth"
print(var,type(var))
var=6.9
print(var,type(var))
var=True
print(var,type(var))
# Out:
# 21 <class 'int'>
# siddharth <class 'str'>
# 6.9 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# ## Calculator

# %%
num1=float(input("enter first number :"))
num2=float(input("enter second number :"))
sum=num1+num2
difference=num1-num2
product=num1*num2
quotient=num1/num2
char=input("enter the operation you want to perform (+, -, *, /) :")

if char == '+':
        print("sum :", sum)
elif char == '-':
    print("difference :", difference)
elif char == '*':
    print("product :", product)
elif char == '/':
    print("quotient :", quotient)
else:
    print("invalid operation")
